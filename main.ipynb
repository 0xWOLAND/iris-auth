# %%
import cv2
import iris
from pathlib import Path
from itertools import combinations

def load_template(img_path):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    result = iris.IRISPipeline()(img, eye_side="left")['iris_template']
    print(f'load template from image: {type(result)}')
    return result

# %%
dataset_path = Path("dataset")
matcher = iris.HammingDistanceMatcher()
threshold = 0.37
NUM_FOLDERS = 3

templates = {}
skipped_counts = {}  # Track skipped templates per folder

# Load templates
for folder in sorted(dataset_path.iterdir())[:NUM_FOLDERS]:
    if not folder.is_dir():
        continue
    print(f"Loading images from {folder.name}")
    folder_templates = []
    skipped = 0
    for img_path in folder.glob("*.jpg"):
        try:
            template = load_template(img_path)
            if template is not None:
                folder_templates.append(template)
            else:
                skipped += 1
        except Exception as e:
            print(f"  Failed to process {img_path.name}: {e}")
            skipped += 1
    templates[folder.name] = folder_templates
    skipped_counts[folder.name] = skipped
    print(f"  Successfully loaded {len(folder_templates)} templates, skipped {skipped} images")
# Out:
# Loading images from 000
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'NoneType'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
#   Successfully loaded 9 templates, skipped 1 images
# Loading images from 001
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'NoneType'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
#   Successfully loaded 9 templates, skipped 1 images
# Loading images from 002
# out: <class 'NoneType'>
# out: <class 'NoneType'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
# out: <class 'iris.io.dataclasses.IrisTemplate'>
#   Successfully loaded 8 templates, skipped 2 images

# %%
templates['000'][0]
# Out:
# IrisTemplate(iris_codes=[array([[[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [False,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True, False],
#         [False, False],
#         [False,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True, False]],
#
#        ...,
#
#        [[False,  True],
#         [False,  True],
#         [False,  True],
#         ...,
#         [False, False],
#         [False, False],
#         [False, False]],
#
#        [[False,  True],
#         [False,  True],
#         [False,  True],
#         ...,
#         [False, False],
#         [False, False],
#         [False, False]],
#
#        [[False,  True],
#         [False,  True],
#         [False,  True],
#         ...,
#         [False, False],
#         [False, False],
#         [False, False]]]), array([[[False, False],
#         [False,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[False, False],
#         [False,  True],
#         [False,  True],
#         ...,
#         [ True,  True],
#         [ True, False],
#         [ True, False]],
#
#        [[False, False],
#         [False, False],
#         [False,  True],
#         ...,
#         [ True,  True],
#         [ True, False],
#         [ True, False]],
#
#        ...,
#
#        [[False,  True],
#         [False,  True],
#         [False,  True],
#         ...,
#         [False, False],
#         [False, False],
#         [False,  True]],
#
#        [[False,  True],
#         [False,  True],
#         [False,  True],
#         ...,
#         [False, False],
#         [False, False],
#         [False,  True]],
#
#        [[False,  True],
#         [False,  True],
#         [False,  True],
#         ...,
#         [False, False],
#         [False,  True],
#         [False,  True]]])], mask_codes=[array([[[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [False,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [False,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        ...,
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True, False]]]), array([[[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        ...,
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True, False],
#         [ True,  True]],
#
#        [[ True,  True],
#         [ True,  True],
#         [ True,  True],
#         ...,
#         [ True,  True],
#         [ True,  True],
#         [ True,  True]]])], iris_code_version='v0.1')

# %%
num_false_diffs = 0   
num_correct_matches = 0

# Compare within folder
print("\nComparing within the same subject:")
for name, tmpl_list in templates.items():
    for t1, t2 in combinations(tmpl_list, 2):
        if t1 is None or t2 is None:
            continue
        print(f't1: {type(t1)}')
        print(f't2: {type(t2)}')
        d = matcher.run(t1, t2)
        print(f"  {name}: distance = {d:.4f} => {'Match' if d < threshold else 'No Match'}")
        if d < threshold:
            num_correct_matches += 1
        else:
            num_false_diffs += 1

print(f"Number of false differences: {num_false_diffs}")
print(f"Number of correct matches: {num_correct_matches}")
# Out:
# Comparing within the same subject:
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2888 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3809 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2236 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.4350 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3890 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3796 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3590 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3948 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3023 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3166 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3270 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2677 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2481 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3121 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3706 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3163 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2405 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1383 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.0957 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1058 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1590 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3883 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3316 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3225 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3043 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3563 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1991 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2072 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.2638 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.3314 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.0911 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1559 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1550 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1311 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.1482 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   000: distance = 0.4625 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3296 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2135 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2898 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2885 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3621 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2848 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3758 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3913 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3046 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2793 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3568 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2969 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2537 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.4385 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3886 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3281 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3270 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3769 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3249 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3951 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3970 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2200 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.1987 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.2091 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3341 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3103 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.4666 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.1911 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3341 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3668 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.1937 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3729 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3089 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3495 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3348 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   001: distance = 0.3380 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.4601 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1495 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1729 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2237 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3473 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1432 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2970 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1876 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1985 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3427 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3348 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1478 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.4231 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1334 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2258 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3227 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1240 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2793 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2562 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3189 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.1365 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2876 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3936 => No Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2447 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3613 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.3340 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2965 => Match
# t1: <class 'iris.io.dataclasses.IrisTemplate'>
# t2: <class 'iris.io.dataclasses.IrisTemplate'>
#   002: distance = 0.2948 => Match
# Number of false differences: 20
# Number of correct matches: 80

# %%
num_false_matches = 0   
num_correct_rejects = 0

# Compare across folders
print("\nComparing across different subjects:")
for (name1, tmpl_list1), (name2, tmpl_list2) in combinations(templates.items(), 2):
    for t1 in tmpl_list1:
        for t2 in tmpl_list2:
            if t1 is None or t2 is None:
                continue
            d = matcher.run(t1, t2)
            print(f"  {name1} vs {name2}: distance = {d:.4f} => {'False Match!' if d < threshold else 'Correct Reject'}")
            if d < threshold:
                num_false_matches += 1
            else:
                num_correct_rejects += 1

print(f"Number of false matches: {num_false_matches}")
print(f"Number of correct rejects: {num_correct_rejects}")
# Out:
# Comparing across different subjects:
#   000 vs 001: distance = 0.4761 => Correct Reject
#   000 vs 001: distance = 0.4796 => Correct Reject
#   000 vs 001: distance = 0.4740 => Correct Reject
#   000 vs 001: distance = 0.4650 => Correct Reject
#   000 vs 001: distance = 0.4642 => Correct Reject
#   000 vs 001: distance = 0.4733 => Correct Reject
#   000 vs 001: distance = 0.4785 => Correct Reject
#   000 vs 001: distance = 0.4530 => Correct Reject
#   000 vs 001: distance = 0.4676 => Correct Reject
#   000 vs 001: distance = 0.4621 => Correct Reject
#   000 vs 001: distance = 0.4598 => Correct Reject
#   000 vs 001: distance = 0.4439 => Correct Reject
#   000 vs 001: distance = 0.4648 => Correct Reject
#   000 vs 001: distance = 0.4536 => Correct Reject
#   000 vs 001: distance = 0.4647 => Correct Reject
#   000 vs 001: distance = 0.4635 => Correct Reject
#   000 vs 001: distance = 0.4701 => Correct Reject
#   000 vs 001: distance = 0.4689 => Correct Reject
#   000 vs 001: distance = 0.4735 => Correct Reject
#   000 vs 001: distance = 0.4695 => Correct Reject
#   000 vs 001: distance = 0.4623 => Correct Reject
#   000 vs 001: distance = 0.4700 => Correct Reject
#   000 vs 001: distance = 0.4715 => Correct Reject
#   000 vs 001: distance = 0.4761 => Correct Reject
#   000 vs 001: distance = 0.4822 => Correct Reject
#   000 vs 001: distance = 0.4827 => Correct Reject
#   000 vs 001: distance = 0.4638 => Correct Reject
#   000 vs 001: distance = 0.4534 => Correct Reject
#   000 vs 001: distance = 0.4759 => Correct Reject
#   000 vs 001: distance = 0.4620 => Correct Reject
#   000 vs 001: distance = 0.4680 => Correct Reject
#   000 vs 001: distance = 0.4649 => Correct Reject
#   000 vs 001: distance = 0.4754 => Correct Reject
#   000 vs 001: distance = 0.4628 => Correct Reject
#   000 vs 001: distance = 0.4593 => Correct Reject
#   000 vs 001: distance = 0.4643 => Correct Reject
#   000 vs 001: distance = 0.4745 => Correct Reject
#   000 vs 001: distance = 0.4729 => Correct Reject
#   000 vs 001: distance = 0.4641 => Correct Reject
#   000 vs 001: distance = 0.4645 => Correct Reject
#   000 vs 001: distance = 0.4536 => Correct Reject
#   000 vs 001: distance = 0.4644 => Correct Reject
#   000 vs 001: distance = 0.4788 => Correct Reject
#   000 vs 001: distance = 0.4732 => Correct Reject
#   000 vs 001: distance = 0.4615 => Correct Reject
#   000 vs 001: distance = 0.4759 => Correct Reject
#   000 vs 001: distance = 0.4676 => Correct Reject
#   000 vs 001: distance = 0.4523 => Correct Reject
#   000 vs 001: distance = 0.4817 => Correct Reject
#   000 vs 001: distance = 0.4625 => Correct Reject
#   000 vs 001: distance = 0.4763 => Correct Reject
#   000 vs 001: distance = 0.4795 => Correct Reject
#   000 vs 001: distance = 0.4783 => Correct Reject
#   000 vs 001: distance = 0.4673 => Correct Reject
#   000 vs 001: distance = 0.4713 => Correct Reject
#   000 vs 001: distance = 0.4637 => Correct Reject
#   000 vs 001: distance = 0.4534 => Correct Reject
#   000 vs 001: distance = 0.4806 => Correct Reject
#   000 vs 001: distance = 0.4624 => Correct Reject
#   000 vs 001: distance = 0.4760 => Correct Reject
#   000 vs 001: distance = 0.4783 => Correct Reject
#   000 vs 001: distance = 0.4882 => Correct Reject
#   000 vs 001: distance = 0.4668 => Correct Reject
#   000 vs 001: distance = 0.4698 => Correct Reject
#   000 vs 001: distance = 0.4629 => Correct Reject
#   000 vs 001: distance = 0.4688 => Correct Reject
#   000 vs 001: distance = 0.4722 => Correct Reject
#   000 vs 001: distance = 0.4701 => Correct Reject
#   000 vs 001: distance = 0.4725 => Correct Reject
#   000 vs 001: distance = 0.4653 => Correct Reject
#   000 vs 001: distance = 0.4564 => Correct Reject
#   000 vs 001: distance = 0.4599 => Correct Reject
#   000 vs 001: distance = 0.4702 => Correct Reject
#   000 vs 001: distance = 0.4741 => Correct Reject
#   000 vs 001: distance = 0.4640 => Correct Reject
#   000 vs 001: distance = 0.4810 => Correct Reject
#   000 vs 001: distance = 0.4823 => Correct Reject
#   000 vs 001: distance = 0.4730 => Correct Reject
#   000 vs 001: distance = 0.4760 => Correct Reject
#   000 vs 001: distance = 0.4779 => Correct Reject
#   000 vs 001: distance = 0.4781 => Correct Reject
#   000 vs 002: distance = 0.4754 => Correct Reject
#   000 vs 002: distance = 0.4709 => Correct Reject
#   000 vs 002: distance = 0.4703 => Correct Reject
#   000 vs 002: distance = 0.4655 => Correct Reject
#   000 vs 002: distance = 0.4715 => Correct Reject
#   000 vs 002: distance = 0.4656 => Correct Reject
#   000 vs 002: distance = 0.4605 => Correct Reject
#   000 vs 002: distance = 0.4690 => Correct Reject
#   000 vs 002: distance = 0.4753 => Correct Reject
#   000 vs 002: distance = 0.4707 => Correct Reject
#   000 vs 002: distance = 0.4735 => Correct Reject
#   000 vs 002: distance = 0.4815 => Correct Reject
#   000 vs 002: distance = 0.4737 => Correct Reject
#   000 vs 002: distance = 0.4689 => Correct Reject
#   000 vs 002: distance = 0.4764 => Correct Reject
#   000 vs 002: distance = 0.4658 => Correct Reject
#   000 vs 002: distance = 0.4793 => Correct Reject
#   000 vs 002: distance = 0.4733 => Correct Reject
#   000 vs 002: distance = 0.4832 => Correct Reject
#   000 vs 002: distance = 0.4709 => Correct Reject
#   000 vs 002: distance = 0.4653 => Correct Reject
#   000 vs 002: distance = 0.4617 => Correct Reject
#   000 vs 002: distance = 0.4759 => Correct Reject
#   000 vs 002: distance = 0.4765 => Correct Reject
#   000 vs 002: distance = 0.4695 => Correct Reject
#   000 vs 002: distance = 0.4747 => Correct Reject
#   000 vs 002: distance = 0.4697 => Correct Reject
#   000 vs 002: distance = 0.4737 => Correct Reject
#   000 vs 002: distance = 0.4682 => Correct Reject
#   000 vs 002: distance = 0.4581 => Correct Reject
#   000 vs 002: distance = 0.4774 => Correct Reject
#   000 vs 002: distance = 0.4490 => Correct Reject
#   000 vs 002: distance = 0.4739 => Correct Reject
#   000 vs 002: distance = 0.4798 => Correct Reject
#   000 vs 002: distance = 0.4645 => Correct Reject
#   000 vs 002: distance = 0.4601 => Correct Reject
#   000 vs 002: distance = 0.4603 => Correct Reject
#   000 vs 002: distance = 0.4607 => Correct Reject
#   000 vs 002: distance = 0.4672 => Correct Reject
#   000 vs 002: distance = 0.4585 => Correct Reject
#   000 vs 002: distance = 0.4698 => Correct Reject
#   000 vs 002: distance = 0.4752 => Correct Reject
#   000 vs 002: distance = 0.4664 => Correct Reject
#   000 vs 002: distance = 0.4553 => Correct Reject
#   000 vs 002: distance = 0.4689 => Correct Reject
#   000 vs 002: distance = 0.4585 => Correct Reject
#   000 vs 002: distance = 0.4682 => Correct Reject
#   000 vs 002: distance = 0.4714 => Correct Reject
#   000 vs 002: distance = 0.4644 => Correct Reject
#   000 vs 002: distance = 0.4792 => Correct Reject
#   000 vs 002: distance = 0.4581 => Correct Reject
#   000 vs 002: distance = 0.4597 => Correct Reject
#   000 vs 002: distance = 0.4626 => Correct Reject
#   000 vs 002: distance = 0.4631 => Correct Reject
#   000 vs 002: distance = 0.4604 => Correct Reject
#   000 vs 002: distance = 0.4644 => Correct Reject
#   000 vs 002: distance = 0.4752 => Correct Reject
#   000 vs 002: distance = 0.4682 => Correct Reject
#   000 vs 002: distance = 0.4854 => Correct Reject
#   000 vs 002: distance = 0.4819 => Correct Reject
#   000 vs 002: distance = 0.4707 => Correct Reject
#   000 vs 002: distance = 0.4662 => Correct Reject
#   000 vs 002: distance = 0.4761 => Correct Reject
#   000 vs 002: distance = 0.4796 => Correct Reject
#   000 vs 002: distance = 0.4817 => Correct Reject
#   000 vs 002: distance = 0.4701 => Correct Reject
#   000 vs 002: distance = 0.4688 => Correct Reject
#   000 vs 002: distance = 0.4584 => Correct Reject
#   000 vs 002: distance = 0.4744 => Correct Reject
#   000 vs 002: distance = 0.4672 => Correct Reject
#   000 vs 002: distance = 0.4735 => Correct Reject
#   000 vs 002: distance = 0.4754 => Correct Reject
#   001 vs 002: distance = 0.4557 => Correct Reject
#   001 vs 002: distance = 0.4738 => Correct Reject
#   001 vs 002: distance = 0.4738 => Correct Reject
#   001 vs 002: distance = 0.4756 => Correct Reject
#   001 vs 002: distance = 0.4681 => Correct Reject
#   001 vs 002: distance = 0.4747 => Correct Reject
#   001 vs 002: distance = 0.4788 => Correct Reject
#   001 vs 002: distance = 0.4603 => Correct Reject
#   001 vs 002: distance = 0.4605 => Correct Reject
#   001 vs 002: distance = 0.4494 => Correct Reject
#   001 vs 002: distance = 0.4620 => Correct Reject
#   001 vs 002: distance = 0.4774 => Correct Reject
#   001 vs 002: distance = 0.4502 => Correct Reject
#   001 vs 002: distance = 0.4725 => Correct Reject
#   001 vs 002: distance = 0.4748 => Correct Reject
#   001 vs 002: distance = 0.4533 => Correct Reject
#   001 vs 002: distance = 0.4661 => Correct Reject
#   001 vs 002: distance = 0.4698 => Correct Reject
#   001 vs 002: distance = 0.4657 => Correct Reject
#   001 vs 002: distance = 0.4739 => Correct Reject
#   001 vs 002: distance = 0.4698 => Correct Reject
#   001 vs 002: distance = 0.4663 => Correct Reject
#   001 vs 002: distance = 0.4730 => Correct Reject
#   001 vs 002: distance = 0.4612 => Correct Reject
#   001 vs 002: distance = 0.4579 => Correct Reject
#   001 vs 002: distance = 0.4638 => Correct Reject
#   001 vs 002: distance = 0.4691 => Correct Reject
#   001 vs 002: distance = 0.4742 => Correct Reject
#   001 vs 002: distance = 0.4622 => Correct Reject
#   001 vs 002: distance = 0.4774 => Correct Reject
#   001 vs 002: distance = 0.4662 => Correct Reject
#   001 vs 002: distance = 0.4597 => Correct Reject
#   001 vs 002: distance = 0.4393 => Correct Reject
#   001 vs 002: distance = 0.4782 => Correct Reject
#   001 vs 002: distance = 0.4617 => Correct Reject
#   001 vs 002: distance = 0.4498 => Correct Reject
#   001 vs 002: distance = 0.4564 => Correct Reject
#   001 vs 002: distance = 0.4749 => Correct Reject
#   001 vs 002: distance = 0.4620 => Correct Reject
#   001 vs 002: distance = 0.4660 => Correct Reject
#   001 vs 002: distance = 0.4658 => Correct Reject
#   001 vs 002: distance = 0.4581 => Correct Reject
#   001 vs 002: distance = 0.4729 => Correct Reject
#   001 vs 002: distance = 0.4672 => Correct Reject
#   001 vs 002: distance = 0.4730 => Correct Reject
#   001 vs 002: distance = 0.4652 => Correct Reject
#   001 vs 002: distance = 0.4706 => Correct Reject
#   001 vs 002: distance = 0.4725 => Correct Reject
#   001 vs 002: distance = 0.4618 => Correct Reject
#   001 vs 002: distance = 0.4571 => Correct Reject
#   001 vs 002: distance = 0.4667 => Correct Reject
#   001 vs 002: distance = 0.4656 => Correct Reject
#   001 vs 002: distance = 0.4699 => Correct Reject
#   001 vs 002: distance = 0.4581 => Correct Reject
#   001 vs 002: distance = 0.4748 => Correct Reject
#   001 vs 002: distance = 0.4547 => Correct Reject
#   001 vs 002: distance = 0.4713 => Correct Reject
#   001 vs 002: distance = 0.4803 => Correct Reject
#   001 vs 002: distance = 0.4745 => Correct Reject
#   001 vs 002: distance = 0.4763 => Correct Reject
#   001 vs 002: distance = 0.4736 => Correct Reject
#   001 vs 002: distance = 0.4633 => Correct Reject
#   001 vs 002: distance = 0.4734 => Correct Reject
#   001 vs 002: distance = 0.4601 => Correct Reject
#   001 vs 002: distance = 0.4688 => Correct Reject
#   001 vs 002: distance = 0.4520 => Correct Reject
#   001 vs 002: distance = 0.4681 => Correct Reject
#   001 vs 002: distance = 0.4601 => Correct Reject
#   001 vs 002: distance = 0.4663 => Correct Reject
#   001 vs 002: distance = 0.4580 => Correct Reject
#   001 vs 002: distance = 0.4689 => Correct Reject
#   001 vs 002: distance = 0.4654 => Correct Reject
# Number of false matches: 0
# Number of correct rejects: 225
